# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests

# %%
# Read in csv
file1 = "../data/birthdata.csv"
Births = pd.read_csv(file1)
print(Births.columns)
# Out:
# Index(['State of Residence', 'Year', 'Mother's Single Race 6', 'Births',
#        'Total Population', 'Birth Rate', 'Female Population',
#        'Fertility Rate'],
#       dtype='object')

# %%
dict = {
    "State of Residence":"state",
    "Year": 'year',
    "Mother's Single Race 6": "race",
    "Births": 'births',
    "Total Population": 'total_pop',
    "Birth Rate": 'birth_rate',
    "Female Population" : "female_pop",
    "Fertility Rate":'fertility_rate'
    }
Births.rename(columns = dict, inplace = True)
display(Births)
# Out:
#         state  year                                       race  births  \
# 0     Alabama  2016           American Indian or Alaska Native     133
# 1     Alabama  2016                                      Asian    1041
# 2     Alabama  2016                  Black or African American   18181
# 3     Alabama  2016  Native Hawaiian or Other Pacific Islander     143
# 4     Alabama  2016                                      White   38778
# ...       ...   ...                                        ...     ...
# 1202  Wyoming  2019                                      Asian      86
# 1203  Wyoming  2019                  Black or African American      79
# 1204  Wyoming  2019  Native Hawaiian or Other Pacific Islander      12
# 1205  Wyoming  2019                                      White    6013
# 1206  Wyoming  2019                         More than one race     153
#
#       total_pop  birth_rate  female_pop  fertility_rate
# 0         33932        3.92        6983           19.05
# 1         68864       15.12       17406           59.81
# 2       1303516       13.95      296019           61.42
# 3          5068       28.22        1245          114.86
# 4       3372524       11.50      616035           62.95
# ...         ...         ...         ...             ...
# 1202       6571       13.09        1973           43.59
# 1203       7467       10.58        1383           57.12
# 1204        596       20.13         118          101.69
# 1205     535371       11.23       98460           61.07
# 1206      12976       11.79        2743           55.78
#
# [1207 rows x 8 columns]

# %%
Births['id'] = range(1, len(Births) + 1)

display(Births)
# Out:
#         state  year                                       race  births  \
# 0     Alabama  2016           American Indian or Alaska Native     133
# 1     Alabama  2016                                      Asian    1041
# 2     Alabama  2016                  Black or African American   18181
# 3     Alabama  2016  Native Hawaiian or Other Pacific Islander     143
# 4     Alabama  2016                                      White   38778
# ...       ...   ...                                        ...     ...
# 1202  Wyoming  2019                                      Asian      86
# 1203  Wyoming  2019                  Black or African American      79
# 1204  Wyoming  2019  Native Hawaiian or Other Pacific Islander      12
# 1205  Wyoming  2019                                      White    6013
# 1206  Wyoming  2019                         More than one race     153
#
#       total_pop  birth_rate  female_pop  fertility_rate    id
# 0         33932        3.92        6983           19.05     1
# 1         68864       15.12       17406           59.81     2
# 2       1303516       13.95      296019           61.42     3
# 3          5068       28.22        1245          114.86     4
# 4       3372524       11.50      616035           62.95     5
# ...         ...         ...         ...             ...   ...
# 1202       6571       13.09        1973           43.59  1203
# 1203       7467       10.58        1383           57.12  1204
# 1204        596       20.13         118          101.69  1205
# 1205     535371       11.23       98460           61.07  1206
# 1206      12976       11.79        2743           55.78  1207
#
# [1207 rows x 9 columns]

# %% [markdown]
# # Extract and Load into Postgres(Heroku)

# %%
#import necessary modules

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy.sql import text
from sqlalchemy.orm import sessionmaker

from flask import Flask, jsonify

connection_string = "postgresql://postgres:postgres@localhost:5432/BirthRate"
engine = create_engine(f'{connection_string}')

# %%
birthrate = '''
    create table birthrate(
    state varchar(100) ,  
    year integer, 
    race varchar(100),
    births integer,
    total_pop integer,
    birth_rate decimal,
    female_pop integer,
    fertility_rate decimal,
    id integer Primary Key
    )
'''

# %%
tables = {'birthrate' : birthrate.strip()          
         }

# %%
for table in tables.keys():
    print(f'dropping the table {table} if it already exists...')
    engine.execute(f'drop table IF EXISTS {table}')
# Out:
# dropping the table birthrate if it already exists...

# %%
for table , script in tables.items():
    print(f'creating the table {table}...')
    engine.execute(f'{script}')
# Out:
# creating the table birthrate...

# %%
Births.to_sql(name='birthrate', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Method 1 Using SQLAlchemy Session Objects

# %%
from sqlalchemy import MetaData
from sqlalchemy.ext.automap import automap_base

metadata = MetaData()

metadata.reflect(engine)
# reflect an existing database into a new model
Base = automap_base(metadata=metadata)
# reflect the tables
Base.prepare()

birthrate, births = Base.classes.birthrate, Base.classes.births

# %%
# We can view all of the classes that automap found

# for mappedclass in Base.classes:
#     print (mappedclass)

Base.classes.keys()
# Out:
# ['births', 'birthrate']

# %%
session = Session(engine)

# %%
    session.close()

# %% [markdown]
# # Method 2 Executing Raw SQL Statements

# %%
from sqlalchemy import inspect
inspector = inspect(engine)

# Get names of tables in database
print(inspector.get_table_names())
# Out:
# ['births', 'birthrate']

# %%
# Get column names for a specific table
print(inspector.get_columns('birthrate'))
# Out:
# [{'name': 'state', 'type': VARCHAR(length=100), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'year', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'race', 'type': VARCHAR(length=100), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'births', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'total_pop', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'birth_rate', 'type': NUMERIC(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'female_pop', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'fertility_rate', 'type': NUMERIC(), 'nullable': True, 'default': None, 'autoincrement': False, 'comment': None}, {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}]

# %%
con = engine.connect()
rs = con.execute("SELECT * FROM birthrate")

print(rs.fetchall())
# Out:
# [('Alabama', 2016, 'American Indian or Alaska Native', 133, 33932, Decimal('3.92'), 6983, Decimal('19.05'), 1), ('Alabama', 2016, 'Asian', 1041, 68864, Decimal('15.12'), 17406, Decimal('59.81'), 2), ('Alabama', 2016, 'Black or African American', 18181, 1303516, Decimal('13.95'), 296019, Decimal('61.42'), 3), ('Alabama', 2016, 'Native Hawaiian or Other Pacific Islander', 143, 5068, Decimal('28.22'), 1245, Decimal('114.86'), 4), ('Alabama', 2016, 'White', 38778, 3372524, Decimal('11.5'), 616035, Decimal('62.95'), 5), ('Alabama', 2016, 'More than one race', 875, 79396, Decimal('11.02'), 15108, Decimal('57.92'), 6), ('Alabama', 2017, 'American Indian or Alaska Native', 150, 34108, Decimal('4.4'), 6902, Decimal('21.73'), 7), ('Alabama', 2017, 'Asian', 1005, 71338, Decimal('14.09'), 17491, Decimal('57.46'), 8), ('Alabama', 2017, 'Black or African American', 18467, 1308214, Decimal('14.12'), 295186, Decimal('62.56'), 9), ('Alabama', 2017, 'Native Hawaiian or Other Pacific Islander', 76, 5239, Decimal('14.51'), 1360, Decimal('55.88'), 10), ('Alabama', 2017, 'White', 38285, 3374131, Decimal('11.35'), 613466, Decimal('62.41'), 11), ('Alabama', 2017, 'More than one race', 958, 81717, Decimal('11.72'), 15544, Decimal('61.63'), 12), ('Alabama', 2018, 'American Indian or Alaska Native', 175, 34375, Decimal('5.09'), 6908, Decimal('25.33'), 13), ('Alabama', 2018, 'Asian', 946, 73167, Decimal('12.93'), 17792, Decimal('53.17'), 14), ('Alabama', 2018, 'Black or African American', 17738, 1310802, Decimal('13.53'), 294175, Decimal('60.3'), 15), ('Alabama', 2018, 'Native Hawaiian or Other Pacific Islander', 122, 5207, Decimal('23.43'), 1333, Decimal('91.52'), 16), ('Alabama', 2018, 'White', 37865, 3379955, Decimal('11.2'), 612438, Decimal('61.83'), 17), ('Alabama', 2018, 'More than one race', 915, 84365, Decimal('10.85'), 16122, Decimal('56.75'), 18), ('Alabama', 2019, 'American Indian or Alaska Native', 189, 34799, Decimal('5.43'), 6979, Decimal('27.08'), 19), ('Alabama', 2019, 'Asian', 930, 73715, Decimal('12.62'), 17775, Decimal('52.32'), 20), ('Alabama', 2019, 'Black or African American', 18401, 1313291, Decimal('14.01'), 293529, Decimal('62.69'), 21), ('Alabama', 2019, 'Native Hawaiian or Other Pacific Islander', 76, 5110, Decimal('14.87'), 1308, Decimal('58.1'), 22), ('Alabama', 2019, 'White', 37932, 3389396, Decimal('11.19'), 613086, Decimal('61.87'), 23), ('Alabama', 2019, 'More than one race', 1087, 86874, Decimal('12.51'), 16641, Decimal('65.32'), 24), ('Alaska', 2016, 'American Indian or Alaska Native', 2195, 112404, Decimal('19.53'), 23300, Decimal('94.21'), 25), ('Alaska', 2016, 'Asian', 729, 46912, Decimal('15.54'), 10682, Decimal('68.25'), 26), ('Alaska', 2016, 'Black or African American', 356, 27898, Decimal('12.76'), 5699, Decimal('62.47'), 27), ('Alaska', 2016, 'Native Hawaiian or Other Pacific Islander', 298, 9870, Decimal('30.19'), 2445, Decimal('121.88'), 28), ('Alaska', 2016, 'White', 6467, 490389, Decimal('13.19'), 93364, Decimal('69.27'), 29), ('Alaska', 2016, 'More than one race', 1164, 54421, Decimal('21.39'), 11881, Decimal('97.97'), 30), ('Alaska', 2017, 'American Indian or Alaska Native', 1985, 112994, Decimal('17.57'), 23382, Decimal('84.89'), 31), ('Alaska', 2017, 'Asian', 720, 47754, Decimal('15.08'), 10947, Decimal('65.77'), 32), ('Alaska', 2017, 'Black or African American', 377, 27595, Decimal('13.66'), 5614, Decimal('67.15'), 33), ('Alaska', 2017, 'Native Hawaiian or Other Pacific Islander', 326, 10084, Decimal('32.33'), 2507, Decimal('130.04'), 34), ('Alaska', 2017, 'White', 5930, 486724, Decimal('12.18'), 91705, Decimal('64.66'), 35), ('Alaska', 2017, 'More than one race', 1107, 54644, Decimal('20.26'), 11917, Decimal('92.89'), 36), ('Alaska', 2018, 'American Indian or Alaska Native', 1956, 113516, Decimal('17.23'), 23502, Decimal('83.23'), 37), ('Alaska', 2018, 'Asian', 659, 49025, Decimal('13.44'), 11391, Decimal('57.85'), 38), ('Alaska', 2018, 'Black or African American', 330, 27942, Decimal('11.81'), 5607, D ...
