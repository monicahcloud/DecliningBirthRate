# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# Read in csv
file1 = "../data/2016.csv"
file2 = "../data/2017.csv"
file3 = "../data/2018.csv"
file4 = "../data/2019.csv"

# %%
table2019 = pd.read_csv(file4)
dict = {
    "2019year":"year2019",  
    "2019births":"births2019"
    }
table2019.rename(columns = dict, inplace = True)
table2019['year2019']=table2019['year2019'].fillna(0).astype('int')
table2019['year2019']=table2019['year2019'].fillna(0).astype('int')
table2019
# Out:
#        state  year2019                                       race  births2019
# 0    Alabama      2019           American Indian or Alaska Native         189
# 1    Alabama      2019                                      Asian         930
# 2    Alabama      2019                  Black or African American       18401
# 3    Alabama      2019  Native Hawaiian or Other Pacific Islander          76
# 4    Alabama      2019                                      White       37932
# ..       ...       ...                                        ...         ...
# 298  Wyoming      2019                                      Asian          86
# 299  Wyoming      2019                  Black or African American          79
# 300  Wyoming      2019  Native Hawaiian or Other Pacific Islander          12
# 301  Wyoming      2019                                      White        6013
# 302  Wyoming      2019                         More than one race         153
#
# [303 rows x 4 columns]

# %%
table2019.replace(0,np.nan)
table2019.fillna("")

table2019 = table2019.drop(columns=['race'])
table2019
# Out:
#        state  year2019  births2019
# 0    Alabama      2019         189
# 1    Alabama      2019         930
# 2    Alabama      2019       18401
# 3    Alabama      2019          76
# 4    Alabama      2019       37932
# ..       ...       ...         ...
# 298  Wyoming      2019          86
# 299  Wyoming      2019          79
# 300  Wyoming      2019          12
# 301  Wyoming      2019        6013
# 302  Wyoming      2019         153
#
# [303 rows x 3 columns]

# %%
table2017.groupby(['state', 'year2017']).sum()
# Out:
#                                births2017
# state                year2017
# Alabama              2017           58941
# Alaska               2017           10445
# Arizona              2017           81872
# Arkansas             2017           37520
# California           2017          471658
# Colorado             2017           64382
# Connecticut          2017           35221
# Delaware             2017           10847
# District of Columbia 2017            9560
# Florida              2017          223630
# Georgia              2017          129243
# Hawaii               2017           17517
# Idaho                2017           22181
# Illinois             2017          149390
# Indiana              2017           82170
# Iowa                 2017           38430
# Kansas               2017           36519
# Kentucky             2017           54752
# Louisiana            2017           61018
# Maine                2017           12294
# Maryland             2017           71641
# ...

# %%
frame2= pd.merge(table2016, table2017, on=["state"])
frame2
# Out:
#         state  year2016  births2016  year2017  births2017
# 0     Alabama      2016         133      2017         150
# 1     Alabama      2016         133      2017        1005
# 2     Alabama      2016         133      2017       18467
# 3     Alabama      2016         133      2017          76
# 4     Alabama      2016         133      2017       38285
# ...       ...       ...         ...       ...         ...
# 1775  Wyoming      2016         160      2017         249
# 1776  Wyoming      2016         160      2017          97
# 1777  Wyoming      2016         160      2017          71
# 1778  Wyoming      2016         160      2017        6306
# 1779  Wyoming      2016         160      2017         171
#
# [1780 rows x 5 columns]

# %%
frame= pd.merge(table2018, table2019, on=["state"])
frame
# Out:
#         state  year2018  2018births  year2019  births2019
# 0     Alabama      2018         175      2019         189
# 1     Alabama      2018         175      2019         930
# 2     Alabama      2018         175      2019       18401
# 3     Alabama      2018         175      2019          76
# 4     Alabama      2018         175      2019       37932
# ...       ...       ...         ...       ...         ...
# 1792  Wyoming      2018         169      2019          86
# 1793  Wyoming      2018         169      2019          79
# 1794  Wyoming      2018         169      2019          12
# 1795  Wyoming      2018         169      2019        6013
# 1796  Wyoming      2018         169      2019         153
#
# [1797 rows x 5 columns]

# %%
tableData = pd.merge(frame, frame2, on=["state"])

tableData
# Out:
#          state  year2018  2018births  year2019  births2019  year2016  \
# 0      Alabama      2018         175      2019         189      2016
# 1      Alabama      2018         175      2019         189      2016
# 2      Alabama      2018         175      2019         189      2016
# 3      Alabama      2018         175      2019         189      2016
# 4      Alabama      2018         175      2019         189      2016
# ...        ...       ...         ...       ...         ...       ...
# 63015  Wyoming      2018         169      2019         153      2016
# 63016  Wyoming      2018         169      2019         153      2016
# 63017  Wyoming      2018         169      2019         153      2016
# 63018  Wyoming      2018         169      2019         153      2016
# 63019  Wyoming      2018         169      2019         153      2016
#
#        births2016  year2017  births2017
# 0             133      2017         150
# 1             133      2017        1005
# ...

# %%
data = tableData.transpose()
data
# Out:
#               0        1        2        3        4        5        6      \
# state       Alabama  Alabama  Alabama  Alabama  Alabama  Alabama  Alabama
# year2018       2018     2018     2018     2018     2018     2018     2018
# 2018births      175      175      175      175      175      175      175
# year2019       2019     2019     2019     2019     2019     2019     2019
# births2019      189      189      189      189      189      189      189
# year2016       2016     2016     2016     2016     2016     2016     2016
# births2016      133      133      133      133      133      133     1041
# year2017       2017     2017     2017     2017     2017     2017     2017
# births2017      150     1005    18467       76    38285      958      150
#
#               7        8        9      ...    63010    63011    63012  \
# state       Alabama  Alabama  Alabama  ...  Wyoming  Wyoming  Wyoming
# year2018       2018     2018     2018  ...     2018     2018     2018
# ...

# %%
#import necessary modules

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy.sql import text
from sqlalchemy.orm import sessionmaker

from flask import Flask, jsonify

connection_string = "postgresql://postgres:postgres@localhost:5432/BirthRate"
engine = create_engine(f'{connection_string}')

# %%
tableData = '''
    create table tableData(
    state varchar(100)primary key,
    year_2019 integer, 
    year2018 integer,
    year2017 integer,
    year2016 integer,
    births2019 integer,
    births2018 integer,
    births2017 integer,
    births2016 integer
     )
'''

# %%
tables = {
          'tableData' : tableData.strip()          
         }

# %%
for table in tables.keys():
    print(f'dropping the table {table} if it already exists...')
    engine.execute(f'drop table IF EXISTS {table}')
# Out:
# dropping the table tableData if it already exists...

# %%
for table , script in tables.items():
    print(f'creating the table {table}...')
    engine.execute(f'{script}')
# Out:
# creating the table tableData...

# %%
data.to_sql(name='tableData', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# TooManyColumns                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# TooManyColumns: tables can have at most 1600 columns
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-69-decda9ade287> in <module>
# ...
